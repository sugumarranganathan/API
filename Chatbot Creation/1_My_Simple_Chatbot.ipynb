# %%
import openai

client = openai.OpenAI(api_key="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")

completion = client.chat.completions.create(model="gpt-3.5-turbo",
                                          messages=[{"role": "user",
                                                     "content": "Give me 3 ideas for apps I could build with openai apis "}])
print(completion.choices[0].message.content)
# Out:
# 1. Mental Health Assistant: An app that uses OpenAI's natural language processing API to provide personalized, empathetic support and guidance for users struggling with mental health issues. The app could offer therapy sessions, coping strategies, and resources based on the user's input and feedback.
#
# 2. Virtual Writing Assistant: An app that leverages OpenAI's language generation API to help users with writing, editing, and brainstorming. The app could suggest creative ideas, correct grammar and spelling errors, and provide feedback on tone and style, making it a valuable tool for writers and students.
#
# 3. News Aggregator with AI Summarization: An app that utilizes OpenAI's text summarization API to aggregate and summarize news articles from various sources. Users could customize their feed by selecting topics of interest and receive concise summaries of the most important news stories. This app would save users time and help them stay informed on current events.

# %%
#Python 3.11
#openai 1.61.1

# %%
#pip install openai==1.61.1
#conda install python=3.11

# %%
#Connects to OpenAI using your API key.
#Sends a question to the GPT-3.5-turbo model.
#Receives a response from the AI.
#Prints the AI’s response.
