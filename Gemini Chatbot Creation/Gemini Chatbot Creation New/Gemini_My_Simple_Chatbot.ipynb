# %% [markdown]
# Install Gemini SDK

# %%
# !pip -q install google-genai

# %% [markdown]
# Read API Key from Colab Secret

# %%
from google.colab import userdata

GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

print("API Key Loaded Successfully!")
# Out:
# API Key Loaded Successfully!

# %% [markdown]
# Initialize Gemini

# %%
from google import genai

client = genai.Client(api_key=GEMINI_API_KEY)

# %% [markdown]
# Ask Gemini

# %%
# !pip -q install -U google-genai

from google.colab import userdata
from google import genai

client = genai.Client(api_key=userdata.get("GEMINI_API_KEY"))

for model in client.models.list():
    print(model.name)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.2/984.2 kB 18.2 MB/s eta 0:00:00
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-omni-flash-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview
# models/gemini-3.5-live-translate-preview

# %%
# !pip -q install -U google-genai

from google.colab import userdata
from google import genai

# Read API Key
GEMINI_API_KEY = userdata.get("GEMINI_API_KEY")

# Create Client
client = genai.Client(api_key=GEMINI_API_KEY)

# Generate Response
response = client.models.generate_content(
    model="gemini-flash-latest",
    contents="Explain Artificial Intelligence in simple words."
)

print(response.text)
# Out:
# In the simplest terms, **Artificial Intelligence (AI)** is when computers and machines are programmed to "think," learn, and make decisions just like humans do.
#
# Here is an easy way to understand it:
#
# ### 1. How is AI different from a regular computer?
# * **A regular computer** is like a calculator. It only does exactly what we tell it to do. If we don’t write a specific instruction for it, it gets stuck.
# * **An AI computer** is more like a puppy. You don't just give it instructions; you give it examples, and it learns from them. Over time, it gets smarter and can make decisions on its own.
#
# ### 2. How does AI learn?
# AI learns through a process called **Machine Learning**.
# Imagine you want to teach a computer to recognize a cat.
# * Instead of writing a complex code describing a cat, you show the computer **millions of pictures of cats**.
# * The computer looks at all the pictures, finds the patterns (like whiskers, pointy ears, and tails), and figures out what a cat looks like on its own.
# * The next time you show it a new picture, it can tell you, "Yes, that is a cat!"
#
# ### 3. AI in your everyday life
# You probably use AI every day without even realizing it:
# * **Netflix or YouTube:** When they recommend a movie or video you might like, AI is analyzing what you watched in the past to guess what you’ll like next.
# * **Siri, Alexa, or Google Assistant:** When you speak to them, AI translates your voice into text, figures out what you want, and talks back to you.
# * **Spam Filters:** Your email inbox uses AI to detect spam emails and hide them from you.
# * **Self-Driving Cars:** Cars like Teslas use AI to "see" the road, spot pedestrians, and drive safely without a human steering.
#
# ### Summary
# If regular software is a **tool** that waits for you to use it, AI is a **partner** that helps you think, predict, and solve problems.

# %%
# Generate Response
response = client.models.generate_content(
    model="gemini-flash-latest",
    contents="Give me 3 ideas for apps I could build with OpenAI APIs"
)

print(response.text)
# Out:
# Here are 3 unique and highly viable app ideas you can build using OpenAI’s current APIs. These ideas span different niches (productivity, education, and hands-on utility) and leverage different capabilities like Vision, Voice, and advanced reasoning.
#
# ---
#
# ### 1. "FixIt Vision" – The Multimodal DIY & Repair Guide
# **The Concept:**
# A mobile app that helps users diagnose and fix household issues (appliances, plumbing, automotive, or electronics) simply by taking a photo or video of the problem.
#
# *   **How it works:**
#     *   A user’s washing machine is showing an error code, or their sink is leaking. They open the app, point their camera at the issue, and record a 5-second video explaining the problem.
#     *   The app diagnoses the issue, lists the exact tools and parts needed, and provides step-by-step interactive instructions.
#     *   Because the user’s hands will be dirty while fixing, the app uses a **voice-first interface**—the user can say "Next step," "Repeat that," or "What tool is this?" hands-free.
# *   **OpenAI APIs to use:**
#     *   **GPT-4o (Vision):** To analyze the images/video frames to identify the appliance model, the damage, or the error code.
#     *   **Realtime API / Whisper:** For hands-free, low-latency voice interaction while the user is actively working.
#     *   **TTS (Text-to-Speech):** To read the step-by-step instructions out loud in a natural voice.
# *   **Why it’s a winner:** It solves a real-world, high-stress pain point. It saves users money on plumbers or technicians, making a premium subscription easy to justify.
#
# ---
#
# ### 2. "Socratic.AI" – The Active-Learning Tutor
# **The Concept:**
# Most AI tutors just give students the answers, which leads to passive learning (and cheating). *Socratic.AI* is an educational app that **refuses to give the answer**. Instead, it uses the Socratic method to guide students to the answer themselves through interactive dialogue.
#
# *   **How it works:**
#     *   The student uploads a syllabus, a homework prompt, or a textbook chapter (e.g., AP Physics or Coding).
#     *   The AI acts as a patient tutor. If the student asks, "How do I solve this math problem?", the AI responds: *"Well, let's look at the variables first. What is the relationship between velocity and time in this equation?"*
#     *   It adapts to the student's grade level and learning style, offering gamified badges and progress tracking.
# *   **OpenAI APIs to use:**
#     *   **Assistants API (with File Search/Vector Store):** Upload the student's textbooks or syllabus as a knowledge base so the AI stays within the curriculum.
#     *   **GPT-4o (Structured Outputs):** To ensure the AI strictly adheres to the Socratic pedagogical style and outputs structured hints rather than direct answers.
# *   **Why it’s a winner:** Parents and teachers hate AI homework helpers that do the work for kids. An AI tutor that actually *teaches* is something schools and parents would gladly pay a monthly subscription for.
#
# ---
#
# ### 3. "AudioDigest" – Personalized Daily Audio Newsletters
# **The Concept:**
# People subscribe to dozens of newsletters, subreddits, and blogs but never have time to read them. *AudioDigest* curates all of a user's favorite text-based content and turns it into a high-quality, personalized 10-minute "morning podcast."
#
# *   **How it works:**
#     *   Users connect their email (for newsletters like Substack), RSS feeds, or save web articles to the app.
#     *   Every morning, the app compiles the most important updates, filters out the clutter, and writes a cohesive, engaging radio-style script summarizing the content.
#     *   The app plays this script using ultra-realistic AI voices. Users can choose the "host" style (e.g., a serious news anchor, a casual tech bro, or a conversational duo).
# *   **OpenAI APIs to use:**
#     *   **GPT-4o:** To analyze, filter, and summarize multiple lengthy articles and rewrite them into a natural-sounding, spoken-word script.
#     *   **TTS (Text-to-Speech) / Custom Voices:** To convert the script into highly engaging, lifelike audio with realistic pauses and intonations.
# *   **Why it’s a winner:** It fits perfectly into daily routines (commuting, making coffee, working out). It solves "information overload" by turning passive reading time into active listening time.
